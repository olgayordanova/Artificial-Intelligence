# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
import nose.tools
# Write your imports here
import numpy as np
import math

# %%
x = [-2.35, 1.22, -3.32, 2.39, -2.77, 
        -3.21, 0.55, -0.81, -2.89, -1.9]
y = [0.58, 6.79, -1.01, 10.32, -0.9,
        -2.16, 6.87, 2.22, -2.05, 0.86]

plt.xlabel = ("Height")

plt.scatter(x, y)
plt.show()

# %%
data_set=pd.read_csv("https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/boot/nuclear.csv")
data_set
# Out:
#     Unnamed: 0    cost   date  t1  t2   cap  pr  ne  ct  bw  cum.n  pt
# 0            1  460.05  68.58  14  46   687   0   1   0   0     14   0
# 1            2  452.99  67.33  10  73  1065   0   0   1   0      1   0
# 2            3  443.22  67.33  10  85  1065   1   0   1   0      1   0
# 3            4  652.32  68.00  11  67  1065   0   1   1   0     12   0
# 4            5  642.23  68.00  11  78  1065   1   1   1   0     12   0
# 5            6  345.39  67.92  13  51   514   0   1   1   0      3   0
# 6            7  272.37  68.17  12  50   822   0   0   0   0      5   0
# 7            8  317.21  68.42  14  59   457   0   0   0   0      1   0
# 8            9  457.12  68.42  15  55   822   1   0   0   0      5   0
# 9           10  690.19  68.33  12  71   792   0   1   1   1      2   0
# 10          11  350.63  68.58  12  64   560   0   0   0   0      3   0
# 11          12  402.59  68.75  13  47   790   0   1   0   0      6   0
# ...

# %%
data_set.cost.mean()
# Out:
# 461.5603124999999

# %%
data_set.dtypes
# Out:
# Unnamed: 0      int64
# cost          float64
# date          float64
# t1              int64
# t2              int64
# cap             int64
# pr              int64
# ne              int64
# ct              int64
# bw              int64
# cum.n           int64
# pt              int64
# dtype: object

# %%
ne= data_set['ne']
ne
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     1
# 5     1
# 6     0
# 7     0
# 8     0
# 9     1
# 10    0
# 11    1
# 12    0
# 13    0
# 14    0
# 15    0
# 16    1
# 17    0
# 18    0
# 19    0
# 20    0
# 21    1
# 22    0
# 23    0
# 24    0
# 25    0
# 26    0
# 27    0
# 28    0
# 29    0
# 30    0
# 31    0
# Name: ne, dtype: int64

# %%
ne.sum()
# Out:
# 8

# %%
data_set
# Out:
#     Unnamed: 0    cost   date  t1  t2   cap  pr  ne  ct  bw  cum.n  pt
# 0            1  460.05  68.58  14  46   687   0   1   0   0     14   0
# 1            2  452.99  67.33  10  73  1065   0   0   1   0      1   0
# 2            3  443.22  67.33  10  85  1065   1   0   1   0      1   0
# 3            4  652.32  68.00  11  67  1065   0   1   1   0     12   0
# 4            5  642.23  68.00  11  78  1065   1   1   1   0     12   0
# 5            6  345.39  67.92  13  51   514   0   1   1   0      3   0
# 6            7  272.37  68.17  12  50   822   0   0   0   0      5   0
# 7            8  317.21  68.42  14  59   457   0   0   0   0      1   0
# 8            9  457.12  68.42  15  55   822   1   0   0   0      5   0
# 9           10  690.19  68.33  12  71   792   0   1   1   1      2   0
# 10          11  350.63  68.58  12  64   560   0   0   0   0      3   0
# 11          12  402.59  68.75  13  47   790   0   1   0   0      6   0
# ...

# %%
plt.scatter(data_set.date,data_set.cost)

# %%
data_set["date"].corr(data_set["cost"])
# Out:
# 0.6104542506093878

# %%
columns = ['cost','pr', 'cap']
df1 = pd.DataFrame(data_set, columns=columns)
df_filtered = df1[df1['pr'] == 1]
df_filtered
# df_filtered.cap.max()
# Out:
#       cost  pr   cap
# 2   443.22   1  1065
# 4   642.23   1  1065
# 8   457.12   1   822
# 17  289.66   1   530
# 19  490.88   1  1050
# 21  665.99   1   828
# 23  608.80   1   821
# 29  280.36   1   886
# 30  217.38   1   745
# 31  270.71   1   886

# %%
datata = pd.read_table('adult.names')
datata
# Out:
#     | This data was extracted from the census bureau database found at
# 0    | http://www.census.gov/ftp/pub/DES/www/welcom...
# 1              | Donor: Ronny Kohavi and Barry Becker,
# 2               |        Data Mining and Visualization
# 3                           |        Silicon Graphics.
# 4       |        e-mail: ronnyk@sgi.com for questions.
# ..                                                 ...
# 101                                 sex: Female, Male.
# 102                          capital-gain: continuous.
# 103                          capital-loss: continuous.
# 104                        hours-per-week: continuous.
# 105  native-country: United-States, Cambodia, Engla...
#
# [106 rows x 1 columns]
